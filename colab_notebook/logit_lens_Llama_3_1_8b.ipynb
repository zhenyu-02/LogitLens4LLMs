# %% [markdown]
# <a href="https://colab.research.google.com/drive/1OcYRKAsVI-me1zmtnhwoQfdyg6y_SVd3?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers

# %%
token = input("Enter your HuggingFace token:")

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

class AttnWrapper(torch.nn.Module):
    def __init__(self, attn):
        super().__init__()
        self.attn = attn
        self.activations = None
        self.add_tensor = None

    def forward(self, *args, **kwargs):
        output = self.attn(*args, **kwargs)
        if self.add_tensor is not None:
            output = (output[0] + self.add_tensor,) + output[1:]
        self.activations = output[0]
        return output

    def reset(self):
        self.activations = None
        self.add_tensor = None

class BlockOutputWrapper(torch.nn.Module):
    def __init__(self, block, lm_head, norm):
        super().__init__()
        self.block = block
        self.lm_head = lm_head
        self.norm = norm
        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None

    def forward(self, x, past_key_value=None, attention_mask=None, position_ids=None, **kwargs):
        output = self.block(x, past_key_value=past_key_value, attention_mask=attention_mask, position_ids=position_ids, **kwargs)

        # Store intermediate outputs
        if isinstance(output, tuple):
            hidden_states = output[0]
        else:
            hidden_states = output

        attention_output = self.get_attn_activations()

        # Calculate and store unembedded outputs
        self.attn_mech_output_unembedded = self.lm_head(self.norm(attention_output)) if attention_output is not None else None
        self.intermediate_res_unembedded = self.lm_head(self.norm(hidden_states))
        self.mlp_output_unembedded = self.lm_head(self.norm(hidden_states))
        self.block_output_unembedded = self.lm_head(self.norm(hidden_states))

        return output

    def attn_add_tensor(self, tensor):
        self.block.self_attn.add_tensor = tensor

    def reset(self):
        self.block.self_attn.reset()
        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None

    def get_attn_activations(self):
        return self.block.self_attn.activations

class Llama3_1_8BHelper:
    def __init__(self, token):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-8B", use_auth_token=token)
        self.model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.1-8B", use_auth_token=token).to(self.device)
        # Wrap attention modules
        for i, layer in enumerate(self.model.model.layers):
            layer.self_attn = AttnWrapper(layer.self_attn)
            self.model.model.layers[i] = BlockOutputWrapper(layer, self.model.lm_head, self.model.model.norm)


    def generate_text(self, prompt, max_length=100):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        generate_ids = self.model.generate(
            inputs.input_ids.to(self.device),
            max_length=max_length,
            pad_token_id=self.tokenizer.eos_token_id
        )
        return self.tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]


    def get_logits(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        with torch.no_grad():
          logits = self.model(inputs.input_ids.to(self.device)).logits
          return logits

    def set_add_attn_output(self, layer, add_output):
        self.model.model.layers[layer].attn_add_tensor(add_output)

    def get_attn_activations(self, layer):
        return self.model.model.layers[layer].get_attn_activations()

    def reset_all(self):
        for layer in self.model.model.layers:
            layer.reset()

    def print_decoded_activations(self, decoded_activations, label):
        softmaxed = torch.nn.functional.softmax(decoded_activations[0][-1], dim=-1)
        values, indices = torch.topk(softmaxed, 10)
        probs_percent = [int(v * 100) for v in values.tolist()]
        tokens = self.tokenizer.batch_decode(indices.unsqueeze(-1))
        print(label, list(zip(tokens, probs_percent)))


    def decode_all_layers(self, text, topk=10, print_attn_mech=True, print_intermediate_res=True, print_mlp=True, print_block=True):
        self.get_logits(text)
        for i, layer in enumerate(self.model.model.layers):
            print(f'Layer {i}: Decoded intermediate outputs')
            if print_attn_mech:
                self.print_decoded_activations(layer.attn_mech_output_unembedded, 'Attention mechanism')
            if print_intermediate_res:
                self.print_decoded_activations(layer.intermediate_res_unembedded, 'Intermediate residual stream')
            if print_mlp:
                self.print_decoded_activations(layer.mlp_output_unembedded, 'MLP output')
            if print_block:
                self.print_decoded_activations(layer.block_output_unembedded, 'Block output')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch_xla/__init__.py:253: UserWarning: `tensorflow` can conflict with `torch-xla`. Prefer `tensorflow-cpu` when using PyTorch/XLA. To silence this warning, `pip uninstall -y tensorflow && pip install tensorflow-cpu`. If you are in a notebook environment such as Colab or Kaggle, restart your notebook runtime afterwards.
#   warnings.warn(

# %%
model = Llama3_1_8BHelper(token)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:823: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
prompt = "The capital of China is "

# %%
model.decode_all_layers(prompt,print_attn_mech=True, print_intermediate_res=True, print_mlp=True,print_block=True)
# Out:
# Layer 0: Decoded intermediate outputs
# Attention mechanism [(':].', 0), (".']", 0), ("'gc", 0), ('./(', 0), ('혼', 0), ('.dataTables', 0), ('\xa0ro', 0), (' nackte', 0), ('internet', 0), ('ickness', 0)]
# Intermediate residual stream [('Disposition', 1), ('RYPTO', 1), (' removeFrom', 0), (' Tanner', 0), ('енту', 0), ('.updateDynamic', 0), ('opher', 0), ('ISON', 0), ('ColumnType', 0), ('allen', 0)]
# MLP output [('Disposition', 1), ('RYPTO', 1), (' removeFrom', 0), (' Tanner', 0), ('енту', 0), ('.updateDynamic', 0), ('opher', 0), ('ISON', 0), ('ColumnType', 0), ('allen', 0)]
# Block output [('Disposition', 1), ('RYPTO', 1), (' removeFrom', 0), (' Tanner', 0), ('енту', 0), ('.updateDynamic', 0), ('opher', 0), ('ISON', 0), ('ColumnType', 0), ('allen', 0)]
# Layer 1: Decoded intermediate outputs
# Attention mechanism [(' المتحدة', 2), (' dap', 0), (' securely', 0), (' �', 0), ('olut', 0), ('autop', 0), ('��', 0), ('emand', 0), ('ewood', 0), ('ď', 0)]
# Intermediate residual stream [('.updateDynamic', 4), ('RYPTO', 1), ('#af', 0), ('っき', 0), ("'gc", 0), ('.scalablytyped', 0), ('_trap', 0), ('ynchronize', 0), ('LastError', 0), ('Disposition', 0)]
# MLP output [('.updateDynamic', 4), ('RYPTO', 1), ('#af', 0), ('っき', 0), ("'gc", 0), ('.scalablytyped', 0), ('_trap', 0), ('ynchronize', 0), ('LastError', 0), ('Disposition', 0)]
# Block output [('.updateDynamic', 4), ('RYPTO', 1), ('#af', 0), ('っき', 0), ("'gc", 0), ('.scalablytyped', 0), ('_trap', 0), ('ynchronize', 0), ('LastError', 0), ('Disposition', 0)]
# Layer 2: Decoded intermediate outputs
# Attention mechanism [('iversit', 2), ('�数', 0), ('#ad', 0), ('NibName', 0), ('#ac', 0), (' ++)\n', 0), ('_PWM', 0), (')frame', 0), ('KL', 0), ('ССР', 0)]
# Intermediate residual stream [('.scalablytyped', 4), ('.updateDynamic', 1), ('taire', 1), ("'gc", 1), ('RYPTO', 0), ('atel', 0), (' intact', 0), ('vae', 0), ('/lists', 0), ('슴', 0)]
# MLP output [('.scalablytyped', 4), ('.updateDynamic', 1), ('taire', 1), ("'gc", 1), ('RYPTO', 0), ('atel', 0), (' intact', 0), ('vae', 0), ('/lists', 0), ('슴', 0)]
# Block output [('.scalablytyped', 4), ('.updateDynamic', 1), ('taire', 1), ("'gc", 1), ('RYPTO', 0), ('atel', 0), (' intact', 0), ('vae', 0), ('/lists', 0), ('슴', 0)]
# Layer 3: Decoded intermediate outputs
# Attention mechanism [('INTR', 2), ('stre', 2), ('intr', 0), (' Wend', 0), ('_SELF', 0), ('resse', 0), ('�', 0), (' bordel', 0), ('figur', 0), ('.jms', 0)]
# Intermediate residual stream [('.scalablytyped', 10), ("'gc", 2), ('.updateDynamic', 1), ('IRMWARE', 0), ('ɵ', 0), ('.createComponent', 0), ('.ActionListener', 0), (')const', 0), ('.inject', 0), ('υγ', 0)]
# MLP output [('.scalablytyped', 10), ("'gc", 2), ('.updateDynamic', 1), ('IRMWARE', 0), ('ɵ', 0), ('.createComponent', 0), ('.ActionListener', 0), (')const', 0), ('.inject', 0), ('υγ', 0)]
# Block output [('.scalablytyped', 10), ("'gc", 2), ('.updateDynamic', 1), ('IRMWARE', 0), ('ɵ', 0), ('.createComponent', 0), ('.ActionListener', 0), (')const', 0), ('.inject', 0), ('υγ', 0)]
# Layer 4: Decoded intermediate outputs
# Attention mechanism [(');}\n\n', 1), ('都市', 1), (' Rape', 0), (' Cast', 0), ('oose', 0), (' Run', 0), (' kvinna', 0), ('.lex', 0), (' sund', 0), ('urga', 0)]
# Intermediate residual stream [("'gc", 9), ('�', 1), (' Yardım', 0), ('.createComponent', 0), ('.scalablytyped', 0), ('IRMWARE', 0), ('unfold', 0), ('_beg', 0), ('사지', 0), ('-equiv', 0)]
# MLP output [("'gc", 9), ('�', 1), (' Yardım', 0), ('.createComponent', 0), ('.scalablytyped', 0), ('IRMWARE', 0), ('unfold', 0), ('_beg', 0), ('사지', 0), ('-equiv', 0)]
# Block output [("'gc", 9), ('�', 1), (' Yardım', 0), ('.createComponent', 0), ('.scalablytyped', 0), ('IRMWARE', 0), ('unfold', 0), ('_beg', 0), ('사지', 0), ('-equiv', 0)]
# Layer 5: Decoded intermediate outputs
# Attention mechanism [('amburger', 1), ('alia', 0), ('illance', 0), ('ắp', 0), ('eprom', 0), ('tul', 0), ('kop', 0), (' Stanley', 0), ('CISION', 0), (' tastes', 0)]
# Intermediate residual stream [('.scalablytyped', 3), ('緒', 1), ("'gc", 1), ('loh', 1), ('oplevel', 0), ('-alist', 0), ('zte', 0), ('jedn', 0), ('Allocation', 0), ('unfold', 0)]
# MLP output [('.scalablytyped', 3), ('緒', 1), ("'gc", 1), ('loh', 1), ('oplevel', 0), ('-alist', 0), ('zte', 0), ('jedn', 0), ('Allocation', 0), ('unfold', 0)]
# Block output [('.scalablytyped', 3), ('緒', 1), ("'gc", 1), ('loh', 1), ('oplevel', 0), ('-alist', 0), ('zte', 0), ('jedn', 0), ('Allocation', 0), ('unfold', 0)]
# Layer 6: Decoded intermediate outputs
# Attention mechanism [('aty', 0), ('ριά', 0), (' eg', 0), (' bran', 0), ('kest', 0), ('allet', 0), (' Eg', 0), ('κρι', 0), (' called', 0), ('668', 0)]
# Intermediate residual stream [('.scalablytyped', 34), ('�', 0), ('unfold', 0), ('òn', 0), ('ایز', 0), ("'gc", 0), ('avn', 0), ('oplevel', 0), ('loh', 0), ('ПО', 0)]
# MLP output [('.scalablytyped', 34), ('�', 0), ('unfold', 0), ('òn', 0), ('ایز', 0), ("'gc", 0), ('avn', 0), ('oplevel', 0), ('loh', 0), ('ПО', 0)]
# Block output [('.scalablytyped', 34), ('�', 0), ('unfold', 0), ('òn', 0), ('ایز', 0), ("'gc", 0), ('avn', 0), ('oplevel', 0), ('loh', 0), ('ПО', 0)]
# Layer 7: Decoded intermediate outputs
# Attention mechanism [('readcr', 9), ('iration', 1), ('bsolute', 1), ('eniable', 1), ('.setViewport', 1), ('antal', 0), ('津', 0), ('endale', 0), ('ativ', 0), (' appe', 0)]
# Intermediate residual stream [('.scalablytyped', 32), ('Radians', 0), ('iale', 0), ('-equiv', 0), ('IPH', 0), ('ikh', 0), (' Henderson', 0), ("'gc", 0), ('Violation', 0), ('ndon', 0)]
# MLP output [('.scalablytyped', 32), ('Radians', 0), ('iale', 0), ('-equiv', 0), ('IPH', 0), ('ikh', 0), (' Henderson', 0), ("'gc", 0), ('Violation', 0), ('ndon', 0)]
# Block output [('.scalablytyped', 32), ('Radians', 0), ('iale', 0), ('-equiv', 0), ('IPH', 0), ('ikh', 0), (' Henderson', 0), ("'gc", 0), ('Violation', 0), ('ndon', 0)]
# Layer 8: Decoded intermediate outputs
# Attention mechanism [('usi', 4), ('bjerg', 0), ('readcrumb', 0), ('ollah', 0), ('elix', 0), ('eper', 0), ('Προ', 0), ('лада', 0), ('rud', 0), ('anut', 0)]
# Intermediate residual stream [('oplevel', 1), ('.scalablytyped', 0), ('.xz', 0), ('.Skin', 0), ('esch', 0), (' -*-\r\n', 0), ('اسه', 0), (' Cater', 0), (' electr', 0), ('psilon', 0)]
# MLP output [('oplevel', 1), ('.scalablytyped', 0), ('.xz', 0), ('.Skin', 0), ('esch', 0), (' -*-\r\n', 0), ('اسه', 0), (' Cater', 0), (' electr', 0), ('psilon', 0)]
# Block output [('oplevel', 1), ('.scalablytyped', 0), ('.xz', 0), ('.Skin', 0), ('esch', 0), (' -*-\r\n', 0), ('اسه', 0), (' Cater', 0), (' electr', 0), ('psilon', 0)]
# Layer 9: Decoded intermediate outputs
# Attention mechanism [('…\n', 28), (' w', 2), ('byn', 1), ('…', 1), (' …\n', 0), (' […]\n', 0), ('…”', 0), (' prec', 0), ('ifar', 0), ('leigh', 0)]
# Intermediate residual stream [(' -*-\r\n', 4), ('Radians', 1), ('asjon', 0), (' electr', 0), ('♪', 0), ('asant', 0), (' Bren', 0), (' Gordon', 0), ('#ab', 0), ('#ad', 0)]
# MLP output [(' -*-\r\n', 4), ('Radians', 1), ('asjon', 0), (' electr', 0), ('♪', 0), ('asant', 0), (' Bren', 0), (' Gordon', 0), ('#ab', 0), ('#ad', 0)]
# Block output [(' -*-\r\n', 4), ('Radians', 1), ('asjon', 0), (' electr', 0), ('♪', 0), ('asant', 0), (' Bren', 0), (' Gordon', 0), ('#ab', 0), ('#ad', 0)]
# Layer 10: Decoded intermediate outputs
# Attention mechanism [(' called', 1), (' en', 0), ('…\n', 0), ('\\:', 0), (' ag', 0), (' ‘', 0), ('rait', 0), ('kB', 0), ('burg', 0), ('berger', 0)]
# Intermediate residual stream [('#ab', 2), (' -*-\r\n', 1), ('.gdx', 0), ('τώ', 0), ('oplevel', 0), ('simd', 0), ('.scalablytyped', 0), ('putc', 0), ('LAY', 0), ('♪', 0)]
# MLP output [('#ab', 2), (' -*-\r\n', 1), ('.gdx', 0), ('τώ', 0), ('oplevel', 0), ('simd', 0), ('.scalablytyped', 0), ('putc', 0), ('LAY', 0), ('♪', 0)]
# Block output [('#ab', 2), (' -*-\r\n', 1), ('.gdx', 0), ('τώ', 0), ('oplevel', 0), ('simd', 0), ('.scalablytyped', 0), ('putc', 0), ('LAY', 0), ('♪', 0)]
# Layer 11: Decoded intermediate outputs
# Attention mechanism [(' burg', 4), (' Shapiro', 0), (' Burg', 0), (' wil', 0), ('lech', 0), ('rien', 0), (' maj', 0), (' mash', 0), ('inv', 0), ('burg', 0)]
# Intermediate residual stream [(' Duffy', 0), ('#ab', 0), ('ModifiedDate', 0), ('министра', 0), (' \u200b\u200b', 0), ('olson', 0), ('εβ', 0), ('Radians', 0), (' U', 0), ('erece', 0)]
# MLP output [(' Duffy', 0), ('#ab', 0), ('ModifiedDate', 0), ('министра', 0), (' \u200b\u200b', 0), ('olson', 0), ('εβ', 0), ('Radians', 0), (' U', 0), ('erece', 0)]
# Block output [(' Duffy', 0), ('#ab', 0), ('ModifiedDate', 0), ('министра', 0), (' \u200b\u200b', 0), ('olson', 0), ('εβ', 0), ('Radians', 0), (' U', 0), ('erece', 0)]
# Layer 12: Decoded intermediate outputs
# Attention mechanism [('uars', 2), ('imas', 1), ('ankan', 1), ('asca', 1), ('urname', 0), ('Courier', 0), ('处', 0), ('ingham', 0), ('elda', 0), (' \\<^', 0)]
# Intermediate residual stream [(' Duffy', 2), ('�n', 0), (' -*-\r\n', 0), ('ModifiedDate', 0), ('قام', 0), (' Ta', 0), ('.::', 0), ('#ab', 0), ('.TypeOf', 0), ('_challenge', 0)]
# MLP output [(' Duffy', 2), ('�n', 0), (' -*-\r\n', 0), ('ModifiedDate', 0), ('قام', 0), (' Ta', 0), ('.::', 0), ('#ab', 0), ('.TypeOf', 0), ('_challenge', 0)]
# Block output [(' Duffy', 2), ('�n', 0), (' -*-\r\n', 0), ('ModifiedDate', 0), ('قام', 0), (' Ta', 0), ('.::', 0), ('#ab', 0), ('.TypeOf', 0), ('_challenge', 0)]
# Layer 13: Decoded intermediate outputs
# Attention mechanism [('appa', 0), ('chein', 0), ('.mvp', 0), ('Bat', 0), ('…\n', 0), ('Pont', 0), (' Pont', 0), ('anja', 0), ('bat', 0), ('674', 0)]
# Intermediate residual stream [('#ab', 0), ('oyer', 0), ('pta', 0), ('cz', 0), (' Ta', 0), ('재', 0), ('zag', 0), ('dfa', 0), ('.::', 0), (' -*-\r\n', 0)]
# MLP output [('#ab', 0), ('oyer', 0), ('pta', 0), ('cz', 0), (' Ta', 0), ('재', 0), ('zag', 0), ('dfa', 0), ('.::', 0), (' -*-\r\n', 0)]
# Block output [('#ab', 0), ('oyer', 0), ('pta', 0), ('cz', 0), (' Ta', 0), ('재', 0), ('zag', 0), ('dfa', 0), ('.::', 0), (' -*-\r\n', 0)]
# Layer 14: Decoded intermediate outputs
# Attention mechanism [(' {?>\n', 1), (' Engel', 0), ('\\views', 0), (' Mandarin', 0), (' McMahon', 0), ('-urlencoded', 0), ('lassian', 0), ('مم', 0), ('land', 0), ('tí', 0)]
# Intermediate residual stream [('#ab', 1), ('ktop', 0), ('#ad', 0), ('#af', 0), (' IReadOnly', 0), ('.datatables', 0), (' Duffy', 0), ('#ac', 0), (' phóng', 0), ('stad', 0)]
# MLP output [('#ab', 1), ('ktop', 0), ('#ad', 0), ('#af', 0), (' IReadOnly', 0), ('.datatables', 0), (' Duffy', 0), ('#ac', 0), (' phóng', 0), ('stad', 0)]
# Block output [('#ab', 1), ('ktop', 0), ('#ad', 0), ('#af', 0), (' IReadOnly', 0), ('.datatables', 0), (' Duffy', 0), ('#ac', 0), (' phóng', 0), ('stad', 0)]
# Layer 15: Decoded intermediate outputs
# Attention mechanism [('ogne', 1), ('ped', 0), ('cor', 0), (' daytime', 0), ('hy', 0), ('/projects', 0), ('-INF', 0), (' Partial', 0), ('bits', 0), ('achen', 0)]
# Intermediate residual stream [('#af', 0), ('#ab', 0), ('.struct', 0), ('landa', 0), ('utas', 0), ('Capital', 0), ('گان', 0), ('#ad', 0), ('Sdk', 0), ('üç', 0)]
# MLP output [('#af', 0), ('#ab', 0), ('.struct', 0), ('landa', 0), ('utas', 0), ('Capital', 0), ('گان', 0), ('#ad', 0), ('Sdk', 0), ('üç', 0)]
# Block output [('#af', 0), ('#ab', 0), ('.struct', 0), ('landa', 0), ('utas', 0), ('Capital', 0), ('گان', 0), ('#ad', 0), ('Sdk', 0), ('üç', 0)]
# Layer 16: Decoded intermediate outputs
# Attention mechanism [('ь', 6), ('-city', 3), ('素', 1), ('ulong', 0), ('367', 0), (' Longitude', 0), (' Capital', 0), (' Capitals', 0), ('狼', 0), ('olec', 0)]
# Intermediate residual stream [('#af', 4), ('#ab', 2), ('eneg', 1), ('Capital', 1), (' Capital', 1), ('�', 0), ('üs', 0), (')frame', 0), ('alem', 0), ('iali', 0)]
# MLP output [('#af', 4), ('#ab', 2), ('eneg', 1), ('Capital', 1), (' Capital', 1), ('�', 0), ('üs', 0), (')frame', 0), ('alem', 0), ('iali', 0)]
# Block output [('#af', 4), ('#ab', 2), ('eneg', 1), ('Capital', 1), (' Capital', 1), ('�', 0), ('üs', 0), (')frame', 0), ('alem', 0), ('iali', 0)]
# Layer 17: Decoded intermediate outputs
# Attention mechanism [(' cities', 12), (' capital', 10), ('城市', 7), (' city', 6), ('cities', 3), (' Cities', 3), (' города', 2), ('เม', 1), ('Cities', 1), (' Forbidden', 1)]
# Intermediate residual stream [(' capital', 4), ('Capital', 2), ('.cap', 1), ('distance', 1), (' Capital', 1), (' distances', 1), (' distance', 1), ('#af', 0), (' CAPITAL', 0), ('üs', 0)]
# MLP output [(' capital', 4), ('Capital', 2), ('.cap', 1), ('distance', 1), (' Capital', 1), (' distances', 1), (' distance', 1), ('#af', 0), (' CAPITAL', 0), ('üs', 0)]
# Block output [(' capital', 4), ('Capital', 2), ('.cap', 1), ('distance', 1), (' Capital', 1), (' distances', 1), (' distance', 1), ('#af', 0), (' CAPITAL', 0), ('üs', 0)]
# Layer 18: Decoded intermediate outputs
# Attention mechanism [(' Neville', 1), ('emsp', 1), ('uffer', 1), ('nbsp', 0), ('rou', 0), ('ClassLoader', 0), ('946', 0), ('cth', 0), ('íc', 0), ('azon', 0)]
# Intermediate residual stream [(' capital', 8), ('Capital', 1), (' Capital', 1), ('RetVal', 1), (' CAPITAL', 1), ('ecz', 0), ('utas', 0), ('_runner', 0), (' distances', 0), ('capital', 0)]
# MLP output [(' capital', 8), ('Capital', 1), (' Capital', 1), ('RetVal', 1), (' CAPITAL', 1), ('ecz', 0), ('utas', 0), ('_runner', 0), (' distances', 0), ('capital', 0)]
# Block output [(' capital', 8), ('Capital', 1), (' Capital', 1), ('RetVal', 1), (' CAPITAL', 1), ('ecz', 0), ('utas', 0), ('_runner', 0), (' distances', 0), ('capital', 0)]
# Layer 19: Decoded intermediate outputs
# Attention mechanism [(' Beijing', 1), ('cheng', 0), ('hua', 0), ('EMU', 0), ('ró', 0), (' Cheng', 0), ('Interop', 0), ('ojí', 0), ('ptal', 0), ('ahu', 0)]
# Intermediate residual stream [(' capital', 24), (' Capital', 17), ('Capital', 12), (' CAPITAL', 4), (' distance', 2), ('capital', 2), (' Distance', 1), ('distance', 1), (' distances', 0), (' miles', 0)]
# MLP output [(' capital', 24), (' Capital', 17), ('Capital', 12), (' CAPITAL', 4), (' distance', 2), ('capital', 2), (' Distance', 1), ('distance', 1), (' distances', 0), (' miles', 0)]
# Block output [(' capital', 24), (' Capital', 17), ('Capital', 12), (' CAPITAL', 4), (' distance', 2), ('capital', 2), (' Distance', 1), ('distance', 1), (' distances', 0), (' miles', 0)]
# Layer 20: Decoded intermediate outputs
# Attention mechanism [('occer', 1), ('osa', 0), ('phy', 0), ('ryo', 0), ('orst', 0), (' �', 0), ('563', 0), ('ifa', 0), ('elling', 0), ('nze', 0)]
# Intermediate residual stream [(' Capital', 31), (' capital', 24), ('Capital', 8), (' CAPITAL', 2), ('capital', 1), (' Capitals', 0), ('-capital', 0), (' distance', 0), (' 北京', 0), ('گان', 0)]
# MLP output [(' Capital', 31), (' capital', 24), ('Capital', 8), (' CAPITAL', 2), ('capital', 1), (' Capitals', 0), ('-capital', 0), (' distance', 0), (' 北京', 0), ('گان', 0)]
# Block output [(' Capital', 31), (' capital', 24), ('Capital', 8), (' CAPITAL', 2), ('capital', 1), (' Capitals', 0), ('-capital', 0), (' distance', 0), (' 北京', 0), ('گان', 0)]
# Layer 21: Decoded intermediate outputs
# Attention mechanism [('izza', 1), ('ocaly', 0), ('arily', 0), (' Roose', 0), ('allo', 0), ('argout', 0), ('sert', 0), ('armac', 0), ('acco', 0), ('otate', 0)]
# Intermediate residual stream [(' Capital', 18), (' capital', 9), ('Capital', 6), (' CAPITAL', 3), ('capital', 3), ('-capital', 1), (' distance', 1), ('گان', 0), (' east', 0), (' 北京', 0)]
# MLP output [(' Capital', 18), (' capital', 9), ('Capital', 6), (' CAPITAL', 3), ('capital', 3), ('-capital', 1), (' distance', 1), ('گان', 0), (' east', 0), (' 北京', 0)]
# Block output [(' Capital', 18), (' capital', 9), ('Capital', 6), (' CAPITAL', 3), ('capital', 3), ('-capital', 1), (' distance', 1), ('گان', 0), (' east', 0), (' 北京', 0)]
# Layer 22: Decoded intermediate outputs
# Attention mechanism [(' hours', 17), (' miles', 7), ('距', 1), ('-hours', 1), (' distance', 1), ('km', 1), ('ologne', 0), ('hours', 0), ('distance', 0), ('距离', 0)]
# Intermediate residual stream [(' Capital', 9), (' capital', 6), (' CAPITAL', 2), (' thousands', 2), (' Beijing', 2), ('Capital', 1), (' 北京', 1), (' distance', 1), (' miles', 1), ('capital', 0)]
# MLP output [(' Capital', 9), (' capital', 6), (' CAPITAL', 2), (' thousands', 2), (' Beijing', 2), ('Capital', 1), (' 北京', 1), (' distance', 1), (' miles', 1), ('capital', 0)]
# Block output [(' Capital', 9), (' capital', 6), (' CAPITAL', 2), (' thousands', 2), (' Beijing', 2), ('Capital', 1), (' 北京', 1), (' distance', 1), (' miles', 1), ('capital', 0)]
# Layer 23: Decoded intermediate outputs
# Attention mechanism [(' Cat', 1), ('Cat', 0), ('ázd', 0), (' Gratuit', 0), (' cat', 0), (' Clyde', 0), ('leared', 0), ('Listing', 0), ('획', 0), ('opr', 0)]
# Intermediate residual stream [(' Beijing', 20), (' thousands', 13), (' 北京', 6), ('北京', 1), (' capital', 1), (' Capital', 1), (' miles', 0), (' millennia', 0), (' Cha', 0), ('awe', 0)]
# MLP output [(' Beijing', 20), (' thousands', 13), (' 北京', 6), ('北京', 1), (' capital', 1), (' Capital', 1), (' miles', 0), (' millennia', 0), (' Cha', 0), ('awe', 0)]
# Block output [(' Beijing', 20), (' thousands', 13), (' 北京', 6), ('北京', 1), (' capital', 1), (' Capital', 1), (' miles', 0), (' millennia', 0), (' Cha', 0), ('awe', 0)]
# Layer 24: Decoded intermediate outputs
# Attention mechanism [(' Huffman', 1), (':\n', 1), ('.cn', 1), ('\n', 1), ('iso', 1), ('ISO', 1), ('uder', 1), ('ンツ', 0), (' Beijing', 0), (' Chinese', 0)]
# Intermediate residual stream [(' Beijing', 24), (' thousands', 5), (' 北京', 2), (' Cha', 1), (' capital', 1), ('北京', 1), (' Capital', 0), ('uth', 0), (' Gordon', 0), ('awe', 0)]
# MLP output [(' Beijing', 24), (' thousands', 5), (' 北京', 2), (' Cha', 1), (' capital', 1), ('北京', 1), (' Capital', 0), ('uth', 0), (' Gordon', 0), ('awe', 0)]
# Block output [(' Beijing', 24), (' thousands', 5), (' 北京', 2), (' Cha', 1), (' capital', 1), ('北京', 1), (' Capital', 0), ('uth', 0), (' Gordon', 0), ('awe', 0)]
# Layer 25: Decoded intermediate outputs
# Attention mechanism [('.SwingConstants', 1), ('tors', 0), ('mighty', 0), ('sim', 0), (' ', 0), ('řes', 0), ('cak', 0), ('etros', 0), ('subtype', 0), (' Ey', 0)]
# Intermediate residual stream [(' Beijing', 32), (' thousands', 4), (' 北京', 2), (' Cha', 1), ('北京', 1), ('/fw', 0), ('tim', 0), (' China', 0), ('bj', 0), ('awe', 0)]
# MLP output [(' Beijing', 32), (' thousands', 4), (' 北京', 2), (' Cha', 1), ('北京', 1), ('/fw', 0), ('tim', 0), (' China', 0), ('bj', 0), ('awe', 0)]
# Block output [(' Beijing', 32), (' thousands', 4), (' 北京', 2), (' Cha', 1), ('北京', 1), ('/fw', 0), ('tim', 0), (' China', 0), ('bj', 0), ('awe', 0)]
# Layer 26: Decoded intermediate outputs
# Attention mechanism [(' &', 1), (' (', 0), (' @', 0), ('ickets', 0), (' ing', 0), ('fp', 0), ('ckett', 0), ('@@', 0), ('омен', 0), (' \xa0', 0)]
# Intermediate residual stream [(' Beijing', 12), (' Cha', 1), ('uth', 0), ('tim', 0), (' thousands', 0), ('awe', 0), ('suz', 0), ('北京', 0), (' 北京', 0), ('unction', 0)]
# MLP output [(' Beijing', 12), (' Cha', 1), ('uth', 0), ('tim', 0), (' thousands', 0), ('awe', 0), ('suz', 0), ('北京', 0), (' 北京', 0), ('unction', 0)]
# Block output [(' Beijing', 12), (' Cha', 1), ('uth', 0), ('tim', 0), (' thousands', 0), ('awe', 0), ('suz', 0), ('北京', 0), (' 北京', 0), ('unction', 0)]
# Layer 27: Decoded intermediate outputs
# Attention mechanism [(' and', 1), (' –', 1), ('yn', 0), (' Larson', 0), (' Lebens', 0), (' --', 0), ('712', 0), (' Hil', 0), ('ur', 0), (' etc', 0)]
# Intermediate residual stream [(' Beijing', 2), (' Cha', 1), ('awe', 1), ('unction', 0), ('uth', 0), ('ousel', 0), ('suz', 0), ('vil', 0), ('tim', 0), ('uts', 0)]
# MLP output [(' Beijing', 2), (' Cha', 1), ('awe', 1), ('unction', 0), ('uth', 0), ('ousel', 0), ('suz', 0), ('vil', 0), ('tim', 0), ('uts', 0)]
# Block output [(' Beijing', 2), (' Cha', 1), ('awe', 1), ('unction', 0), ('uth', 0), ('ousel', 0), ('suz', 0), ('vil', 0), ('tim', 0), ('uts', 0)]
# Layer 28: Decoded intermediate outputs
# Attention mechanism [('umed', 4), ('iggins', 1), ('.gc', 1), ('::-', 0), (' grop', 0), ('ым', 0), ('徒', 0), ('urve', 0), ('chwitz', 0), ('ジュ', 0)]
# Intermediate residual stream [('uth', 4), (' Beijing', 1), ('inger', 1), ('oun', 0), ('unction', 0), ('ousel', 0), ('awe', 0), ('suz', 0), ('oub', 0), ('ics', 0)]
# MLP output [('uth', 4), (' Beijing', 1), ('inger', 1), ('oun', 0), ('unction', 0), ('ousel', 0), ('awe', 0), ('suz', 0), ('oub', 0), ('ics', 0)]
# Block output [('uth', 4), (' Beijing', 1), ('inger', 1), ('oun', 0), ('unction', 0), ('ousel', 0), ('awe', 0), ('suz', 0), ('oub', 0), ('ics', 0)]
# Layer 29: Decoded intermediate outputs
# Attention mechanism [(' (', 58), ('.', 10), (',', 9), (' ', 8), (' [', 2), (' and', 0), (' -', 0), ('.', 0), ('\xa0', 0), (' in', 0)]
# Intermediate residual stream [('uth', 14), ('ube', 2), ('ert', 1), ('ous', 1), ('erti', 1), ('inger', 1), ('iber', 1), ('suz', 1), ('oub', 0), ('ession', 0)]
# MLP output [('uth', 14), ('ube', 2), ('ert', 1), ('ous', 1), ('erti', 1), ('inger', 1), ('iber', 1), ('suz', 1), ('oub', 0), ('ession', 0)]
# Block output [('uth', 14), ('ube', 2), ('ert', 1), ('ous', 1), ('erti', 1), ('inger', 1), ('iber', 1), ('suz', 1), ('oub', 0), ('ession', 0)]
# Layer 30: Decoded intermediate outputs
# Attention mechanism [(' Be', 98), ('Be', 0), (' BE', 0), ('.Be', 0), ('(Be', 0), (' Beck', 0), (' -', 0), (' Bea', 0), (' P', 0), (' Beast', 0)]
# Intermediate residual stream [('uth', 46), ('ous', 6), ('ube', 4), ('ick', 2), ('ert', 1), ('unction', 1), ('rome', 1), ('ession', 1), ('ics', 1), ('ount', 0)]
# MLP output [('uth', 46), ('ous', 6), ('ube', 4), ('ick', 2), ('ert', 1), ('unction', 1), ('rome', 1), ('ession', 1), ('ics', 1), ('ount', 0)]
# Block output [('uth', 46), ('ous', 6), ('ube', 4), ('ick', 2), ('ert', 1), ('unction', 1), ('rome', 1), ('ession', 1), ('ics', 1), ('ount', 0)]
# Layer 31: Decoded intermediate outputs
# Attention mechanism [(' Beijing', 37), (' China', 6), (' ', 4), ('\xa0', 3), ('?', 2), ('.', 2), ('…', 2), ('...', 2), (';', 2), (' Chinese', 2)]
# Intermediate residual stream [('1', 9), ('2', 8), ('3', 5), ('7', 4), ('\xa0', 4), ('5', 3), ('4', 2), ('8', 2), ('6', 2), ('12', 1)]
# MLP output [('1', 9), ('2', 8), ('3', 5), ('7', 4), ('\xa0', 4), ('5', 3), ('4', 2), ('8', 2), ('6', 2), ('12', 1)]
# Block output [('1', 9), ('2', 8), ('3', 5), ('7', 4), ('\xa0', 4), ('5', 3), ('4', 2), ('8', 2), ('6', 2), ('12', 1)]

# %%
model.decode_all_layers('My favorite dish to eat is',print_attn_mech=False, print_intermediate_res=False, print_mlp=False,print_block=True)
# Out:
# Layer 0: Decoded intermediate outputs
# Block output [('otope', 0), ('OSP', 0), ('/is', 0), ('gın', 0), ('/w', 0), ('ridor', 0), (' disag', 0), ('uo', 0), ('alien', 0), ('consin', 0)]
# Layer 1: Decoded intermediate outputs
# Block output [('��', 3), ('μι', 1), ("'gc", 0), ('gın', 0), ('ジア', 0), ('يث', 0), (' gì', 0), ('psc', 0), ('uali', 0), ('otope', 0)]
# Layer 2: Decoded intermediate outputs
# Block output [('.Areas', 1), ("'gc", 0), ('@mail', 0), ('оск', 0), (' Bair', 0), ('.Criteria', 0), ('embr', 0), ('NECT', 0), ('дах', 0), ('άς', 0)]
# Layer 3: Decoded intermediate outputs
# Block output [("'gc", 2), ('avian', 0), ('ırak', 0), ('▍', 0), ('اکی', 0), ('šak', 0), ('�', 0), ('ディ', 0), ('.Areas', 0), ('>tag', 0)]
# Layer 4: Decoded intermediate outputs
# Block output [('gnu', 0), ('dere', 0), ('ouns', 0), ("'gc", 0), ('控', 0), ('Bes', 0), ('缘', 0), ('ヴァ', 0), ('OMPI', 0), ('_physical', 0)]
# Layer 5: Decoded intermediate outputs
# Block output [('Bes', 1), ('控', 0), ('ůst', 0), ('ynom', 0), ('(exports', 0), ('ospace', 0), ('づ', 0), (' Bes', 0), (' subur', 0), (' ferr', 0)]
# Layer 6: Decoded intermediate outputs
# Block output [(' resil', 1), ('IPHER', 1), ('zte', 1), ('IDGE', 0), ('utherford', 0), ('orest', 0), ('autiful', 0), (' unre', 0), ('ویه', 0), ('.protobuf', 0)]
# Layer 7: Decoded intermediate outputs
# Block output [('autiful', 1), ('inges', 0), ('×\n\n', 0), (' resil', 0), ('cott', 0), (' свя', 0), ('simd', 0), ('ossal', 0), ('celik', 0), (' nack', 0)]
# Layer 8: Decoded intermediate outputs
# Block output [('ozí', 1), ('celik', 0), ('inges', 0), ('�', 0), (' Setter', 0), ('simd', 0), ('utow', 0), ('ájem', 0), ('φα', 0), (' SCO', 0)]
# Layer 9: Decoded intermediate outputs
# Block output [('celik', 2), ('(exports', 0), ('CallCheck', 0), ('ájem', 0), (' McGr', 0), (' SCO', 0), ('坦', 0), ('IVAL', 0), ("'gc", 0), ('/w', 0)]
# Layer 10: Decoded intermediate outputs
# Block output [('iegel', 1), ('(exports', 0), ('altimore', 0), ('celik', 0), ('ájem', 0), (' Yap', 0), (' cil', 0), ('坦', 0), ('.TypeOf', 0), (' Gim', 0)]
# Layer 11: Decoded intermediate outputs
# Block output [('iegel', 1), ('otope', 0), ('.TypeOf', 0), ('celik', 0), ('HAV', 0), ('hyth', 0), ('altimore', 0), ('坦', 0), ('ив', 0), (' ferr', 0)]
# Layer 12: Decoded intermediate outputs
# Block output [('HAV', 0), ('celik', 0), ('_DD', 0), ('chal', 0), ('avar', 0), ('REDIENT', 0), ('obox', 0), ('_HINT', 0), ('deps', 0), ('.TypeOf', 0)]
# Layer 13: Decoded intermediate outputs
# Block output [('(exports', 0), ('omba', 0), ('�', 0), ('otope', 0), ('chal', 0), ('oppins', 0), ('443', 0), ('redi', 0), ('oucher', 0), (' interrog', 0)]
# Layer 14: Decoded intermediate outputs
# Block output [('chal', 1), ('redi', 0), ('ChangedEventArgs', 0), ('LAY', 0), (' interrog', 0), ('#ab', 0), ('ContentLoaded', 0), ('addir', 0), ('_authenticated', 0), ('arkers', 0)]
# Layer 15: Decoded intermediate outputs
# Block output [('hevik', 1), ('#ab', 0), ('redi', 0), ('██', 0), ('ChangedEventArgs', 0), ('createCommand', 0), ('omanip', 0), ('opies', 0), (' humble', 0), ('ssql', 0)]
# Layer 16: Decoded intermediate outputs
# Block output [('#ab', 2), ('#__', 1), ('hevik', 0), (' Clair', 0), ('SKTOP', 0), ('opies', 0), ('ometrics', 0), ('�数', 0), ('redi', 0), ('otope', 0)]
# Layer 17: Decoded intermediate outputs
# Block output [('#ab', 2), ('#__', 1), ('hevik', 0), (" '{@", 0), (' STDMETHODCALLTYPE', 0), ('bsite', 0), (' &___', 0), ('dddd', 0), ('ppers', 0), ('ilians', 0)]
# Layer 18: Decoded intermediate outputs
# Block output [('#ab', 2), ("'gc", 1), ('hevik', 0), ('edes', 0), ('#aa', 0), (" '{@", 0), ('.rdf', 0), ('createCommand', 0), ('██', 0), (' &___', 0)]
# Layer 19: Decoded intermediate outputs
# Block output [('#ab', 1), ('turnstile', 0), ('�', 0), (" '{@", 0), (' probably', 0), ("'gc", 0), ('edException', 0), ('hevik', 0), ('createCommand', 0), ('otope', 0)]
# Layer 20: Decoded intermediate outputs
# Block output [("'gc", 0), ('edException', 0), (' probably', 0), ('�', 0), ('.Deep', 0), (" '{@", 0), ('turnstile', 0), ('yat', 0), ('#ab', 0), ('edback', 0)]
# Layer 21: Decoded intermediate outputs
# Block output [('.Deep', 0), (' Firearms', 0), (' Prostit', 0), (' probably', 0), (' Lover', 0), ('�', 0), ('bsite', 0), ('turnstile', 0), ("'gc", 0), ('██', 0)]
# Layer 22: Decoded intermediate outputs
# Block output [(' las', 1), (' comfort', 1), ('ollo', 0), (' mac', 0), (' Entr', 0), (' Lingu', 0), (' probably', 0), (' pedest', 0), (' Las', 0), ('="__', 0)]
# Layer 23: Decoded intermediate outputs
# Block output [(' las', 2), (' comfort', 1), (' mac', 0), (' Las', 0), (' probably', 0), (' ris', 0), ('ollo', 0), (' Entr', 0), (' pedest', 0), (' Lover', 0)]
# Layer 24: Decoded intermediate outputs
# Block output [(' las', 4), (' mac', 1), (' comfort', 1), (' rot', 0), (' ris', 0), (' Las', 0), (' wings', 0), ('-ste', 0), ('Las', 0), ('las', 0)]
# Layer 25: Decoded intermediate outputs
# Block output [(' las', 5), (' comfort', 1), (' mac', 1), (' stir', 1), (' wings', 0), (' ris', 0), (' ribs', 0), (' rot', 0), (' flank', 0), (' Las', 0)]
# Layer 26: Decoded intermediate outputs
# Block output [(' las', 4), (' wings', 2), (' stir', 2), (' comfort', 2), (' ribs', 1), (' mac', 1), (' ris', 1), (' Wings', 0), (' pad', 0), (' flank', 0)]
# Layer 27: Decoded intermediate outputs
# Block output [(' las', 3), (' stir', 2), (' comfort', 2), (' mac', 2), (' wings', 1), (' pad', 1), (' ris', 1), (' Wings', 1), (' Gy', 1), (' ribs', 1)]
# Layer 28: Decoded intermediate outputs
# Block output [(' las', 5), (' pad', 4), (' wings', 2), (' mac', 2), (' stir', 2), (' comfort', 1), (' ris', 1), (' Gy', 0), (' ribs', 0), (' Pad', 0)]
# Layer 29: Decoded intermediate outputs
# Block output [(' las', 3), (' stir', 3), (' mac', 2), (' pad', 2), (' wings', 2), (' comfort', 1), (' ribs', 1), (' Pad', 1), (' bib', 1), (' shepherd', 0)]
# Layer 30: Decoded intermediate outputs
# Block output [(' stir', 6), (' bib', 5), (' Ris', 1), (' chim', 1), (' wings', 1), (' las', 1), (' pad', 1), (' lingu', 1), (' comfort', 1), (' probably', 0)]
# Layer 31: Decoded intermediate outputs
# Block output [(' a', 6), (' the', 4), (' my', 3), (' chicken', 2), (' pasta', 2), (' probably', 2), (' fried', 2), (' spaghetti', 1), (' pizza', 1), (' sushi', 1)]

# %%
=+model.reset_all()
layer = 14
model.get_logits('bananas')
attn = model.get_attn_activations(layer)
last_token_attn = attn[0][-1]
model.set_add_attn_output(layer, 0.6*last_token_attn)

# %%
model.generate_text(prompt, max_length=50)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-94c224b9dd42> in <cell line: 0>()
# ----> 1 model.generate_text(prompt, max_length=50)
#
# <ipython-input-3-66db30edc4a5> in generate_text(self, prompt, max_length)
#      76     def generate_text(self, prompt, max_length=100):
#      77         inputs = self.tokenizer(prompt, return_tensors="pt")
# ---> 78         generate_ids = self.model.generate(
#      79             inputs.input_ids.to(self.device),
#      80             max_length=max_length,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2253
#    2254             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255             result = self._sample(
#    2256                 input_ids,
#    2257                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3255                 is_prefill = False
#    3256             else:
# -> 3257                 outputs = model_forward(**model_inputs, return_dict=True)
#    3258
#    3259             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#     832
#     833         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 834         outputs = self.model(
#     835             input_ids=input_ids,
#     836             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     590                 )
#     591             else:
# --> 592                 layer_outputs = decoder_layer(
#     593                     hidden_states,
#     594                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-3-66db30edc4a5> in forward(self, x, past_key_value, attention_mask, position_ids, **kwargs)
#      32
#      33     def forward(self, x, past_key_value=None, attention_mask=None, position_ids=None, **kwargs):
# ---> 34         output = self.block(x, past_key_value=past_key_value, attention_mask=attention_mask, position_ids=position_ids, **kwargs)
#      35
#      36         # Store intermediate outputs
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     349         residual = hidden_states
#     350         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 351         hidden_states = self.mlp(hidden_states)
#     352         hidden_states = residual + hidden_states
#     353
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     187
#     188     def forward(self, x):
# --> 189         down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     190         return down_proj
#     191
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
model.reset_all()
