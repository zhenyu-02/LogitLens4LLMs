# %% [markdown]
# <a href="https://colab.research.google.com/drive/1xpBQSnukiNPka2oQDtLd7sKdQ0gt74PU?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

class AttnWrapper(torch.nn.Module):
    def __init__(self, attn):
        super().__init__()
        self.attn = attn
        self.activations = None
        self.add_tensor = None

    def forward(self, *args, **kwargs):
        output = self.attn(*args, **kwargs)
        if self.add_tensor is not None:
            output = (output[0] + self.add_tensor,) + output[1:]
        self.activations = output[0]
        return output

    def reset(self):
        self.activations = None
        self.add_tensor = None

class BlockOutputWrapper(torch.nn.Module):
    def __init__(self, block, lm_head, norm):
        super().__init__()
        self.block = block
        self.lm_head = lm_head
        self.norm = norm
        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None

    def forward(self, x, past_key_value=None, attention_mask=None, position_ids=None, **kwargs):
        output = self.block(x, past_key_value=past_key_value, attention_mask=attention_mask,
                          position_ids=position_ids, **kwargs)

        if isinstance(output, tuple):
            hidden_states = output[0]
        else:
            hidden_states = output

        attention_output = self.get_attn_activations()

        self.attn_mech_output_unembedded = self.lm_head(self.norm(attention_output)) if attention_output is not None else None
        self.intermediate_res_unembedded = self.lm_head(self.norm(hidden_states))
        self.mlp_output_unembedded = self.lm_head(self.norm(hidden_states))
        self.block_output_unembedded = self.lm_head(self.norm(hidden_states))

        return output

    def attn_add_tensor(self, tensor):
        self.block.self_attn.add_tensor = tensor

    def reset(self):
        self.block.self_attn.reset()
        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None

    def get_attn_activations(self):
        return self.block.self_attn.activations

class Qwen2Helper:
    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")
        self.model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-7B-Instruct").to(self.device)

        # Wrap attention modules
        for i, layer in enumerate(self.model.model.layers):
            layer.self_attn = AttnWrapper(layer.self_attn)
            self.model.model.layers[i] = BlockOutputWrapper(layer, self.model.lm_head, self.model.model.norm)

    def generate_text(self, prompt, max_length=100):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        generate_ids = self.model.generate(
            inputs.input_ids.to(self.device),
            max_length=max_length,
            pad_token_id=self.tokenizer.eos_token_id
        )
        return self.tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

    def get_logits(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        with torch.no_grad():
            logits = self.model(inputs.input_ids.to(self.device)).logits
        return logits

    def set_add_attn_output(self, layer, add_output):
        self.model.model.layers[layer].attn_add_tensor(add_output)

    def get_attn_activations(self, layer):
        return self.model.model.layers[layer].get_attn_activations()

    def reset_all(self):
        for layer in self.model.model.layers:
            layer.reset()

    def print_decoded_activations(self, decoded_activations, label):
        softmaxed = torch.nn.functional.softmax(decoded_activations[0][-1], dim=-1)
        values, indices = torch.topk(softmaxed, 10)
        probs_percent = [int(v * 100) for v in values.tolist()]
        tokens = self.tokenizer.batch_decode(indices.unsqueeze(-1))
        print(label, list(zip(tokens, probs_percent)))

    def decode_all_layers(self, text, topk=10, print_attn_mech=True, print_intermediate_res=True,
                         print_mlp=True, print_block=True):
        self.get_logits(text)
        for i, layer in enumerate(self.model.model.layers):
            print(f'Layer {i}: Decoded intermediate outputs')
            if print_attn_mech:
                self.print_decoded_activations(layer.attn_mech_output_unembedded, 'Attention mechanism')
            if print_intermediate_res:
                self.print_decoded_activations(layer.intermediate_res_unembedded, 'Intermediate residual stream')
            if print_mlp:
                self.print_decoded_activations(layer.mlp_output_unembedded, 'MLP output')
            if print_block:
                self.print_decoded_activations(layer.block_output_unembedded, 'Block output')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch_xla/__init__.py:253: UserWarning: `tensorflow` can conflict with `torch-xla`. Prefer `tensorflow-cpu` when using PyTorch/XLA. To silence this warning, `pip uninstall -y tensorflow && pip install tensorflow-cpu`. If you are in a notebook environment such as Colab or Kaggle, restart your notebook runtime afterwards.
#   warnings.warn(

# %%
model = Qwen2Helper()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]

# %%
prompt = "The capital of China is "

# %%
model.decode_all_layers(prompt,print_attn_mech=True, print_intermediate_res=True, print_mlp=True,print_block=True)
# Out:
# Layer 0: Decoded intermediate outputs
# Attention mechanism [(' strugg', 27), ('从根本', 10), ('准', 3), ('냄', 2), ('-strokes', 2), ('icester', 1), ('1', 1), ('ことがあります', 1), (' PartialView', 0), ('ProgressHUD', 0)]
# Intermediate residual stream [('从根本', 62), ('嘞', 2), (' strugg', 1), (' PartialView', 1), ('.MouseAdapter', 0), (' Beste', 0), ('냄', 0), ('始建', 0), ('suming', 0), ('icester', 0)]
# MLP output [('从根本', 62), ('嘞', 2), (' strugg', 1), (' PartialView', 1), ('.MouseAdapter', 0), (' Beste', 0), ('냄', 0), ('始建', 0), ('suming', 0), ('icester', 0)]
# Block output [('从根本', 62), ('嘞', 2), (' strugg', 1), (' PartialView', 1), ('.MouseAdapter', 0), (' Beste', 0), ('냄', 0), ('始建', 0), ('suming', 0), ('icester', 0)]
# Layer 1: Decoded intermediate outputs
# Attention mechanism [(' 自动生成', 11), ('-svg', 6), (' TORT', 3), (' bureaucr', 2), (' MySqlConnection', 2), (' disadv', 2), ('性价', 2), ('颏', 1), (' uncert', 1), ('瑀', 1)]
# Intermediate residual stream [(' strugg', 69), ('从根本', 12), (' bureaucr', 2), ('始建', 0), ('icester', 0), ('.RowCount', 0), (' Beste', 0), (' sophistic', 0), ('\\Id', 0), ('1', 0)]
# MLP output [(' strugg', 69), ('从根本', 12), (' bureaucr', 2), ('始建', 0), ('icester', 0), ('.RowCount', 0), (' Beste', 0), (' sophistic', 0), ('\\Id', 0), ('1', 0)]
# Block output [(' strugg', 69), ('从根本', 12), (' bureaucr', 2), ('始建', 0), ('icester', 0), ('.RowCount', 0), (' Beste', 0), (' sophistic', 0), ('\\Id', 0), ('1', 0)]
# Layer 2: Decoded intermediate outputs
# Attention mechanism [('浔', 22), ('derabad', 1), ('akh', 1), ('ine', 1), ('遘', 0), ('Ral', 0), ('.RemoveAll', 0), ('簇', 0), ('peng', 0), ('dbName', 0)]
# Intermediate residual stream [(' strugg', 74), (' bureaucr', 4), ('从根本', 3), ('.RowCount', 1), ('始建', 1), ('诩', 0), ('1', 0), ('icester', 0), ('/Dk', 0), ('냄', 0)]
# MLP output [(' strugg', 74), (' bureaucr', 4), ('从根本', 3), ('.RowCount', 1), ('始建', 1), ('诩', 0), ('1', 0), ('icester', 0), ('/Dk', 0), ('냄', 0)]
# Block output [(' strugg', 74), (' bureaucr', 4), ('从根本', 3), ('.RowCount', 1), ('始建', 1), ('诩', 0), ('1', 0), ('icester', 0), ('/Dk', 0), ('냄', 0)]
# Layer 3: Decoded intermediate outputs
# Attention mechanism [(' 自动生成', 53), ('สามาร', 3), (' 生命周期', 3), ('/respond', 2), ('℉', 1), ('lijah', 0), ('劫', 0), ('扮演游戏', 0), (' masturbating', 0), ('STITUTE', 0)]
# Intermediate residual stream [(' strugg', 76), ('从根本', 11), ('/Dk', 2), ('始建', 1), (' bureaucr', 0), (' FindObjectOfType', 0), ('냄', 0), ('-wow', 0), ('traîn', 0), (' Dumpster', 0)]
# MLP output [(' strugg', 76), ('从根本', 11), ('/Dk', 2), ('始建', 1), (' bureaucr', 0), (' FindObjectOfType', 0), ('냄', 0), ('-wow', 0), ('traîn', 0), (' Dumpster', 0)]
# Block output [(' strugg', 76), ('从根本', 11), ('/Dk', 2), ('始建', 1), (' bureaucr', 0), (' FindObjectOfType', 0), ('냄', 0), ('-wow', 0), ('traîn', 0), (' Dumpster', 0)]
# Layer 4: Decoded intermediate outputs
# Attention mechanism [(')data', 16), ('ialized', 14), (".':", 3), (':;"', 3), ('quisitions', 2), ('/Graphics', 1), ('ДЕ', 1), ('lsi', 1), ('________________________________________________________________', 1), ('iteDatabase', 0)]
# Intermediate residual stream [(' strugg', 49), ('从根本', 19), ('/Dk', 3), (' FindObjectOfType', 2), ('-lnd', 1), ('icester', 0), ('始建', 0), ('냄', 0), ('bart', 0), ('weeney', 0)]
# MLP output [(' strugg', 49), ('从根本', 19), ('/Dk', 3), (' FindObjectOfType', 2), ('-lnd', 1), ('icester', 0), ('始建', 0), ('냄', 0), ('bart', 0), ('weeney', 0)]
# Block output [(' strugg', 49), ('从根本', 19), ('/Dk', 3), (' FindObjectOfType', 2), ('-lnd', 1), ('icester', 0), ('始建', 0), ('냄', 0), ('bart', 0), ('weeney', 0)]
# Layer 5: Decoded intermediate outputs
# Attention mechanism [('鹬', 4), ('趸', 3), ('性价', 2), ('egis', 2), ('프로그', 2), ('普遍存在', 1), ('scrição', 1), ('.Networking', 1), ('つつ', 1), ('逛街', 1)]
# Intermediate residual stream [('从根本', 66), (' strugg', 8), ('icester', 3), ('/Dk', 2), ('weeney', 0), ('strap', 0), ('냄', 0), ('那么容易', 0), ('始建', 0), ('\\Id', 0)]
# MLP output [('从根本', 66), (' strugg', 8), ('icester', 3), ('/Dk', 2), ('weeney', 0), ('strap', 0), ('냄', 0), ('那么容易', 0), ('始建', 0), ('\\Id', 0)]
# Block output [('从根本', 66), (' strugg', 8), ('icester', 3), ('/Dk', 2), ('weeney', 0), ('strap', 0), ('냄', 0), ('那么容易', 0), ('始建', 0), ('\\Id', 0)]
# Layer 6: Decoded intermediate outputs
# Attention mechanism [('ogenerated', 12), (' intox', 6), ("'&&", 4), (' scaleX', 2), ('antro', 1), ('ġ', 1), ('ocrats', 1), (' Humph', 1), ('bove', 1), ('了好几', 1)]
# Intermediate residual stream [('/Dk', 50), ('weeney', 11), ('icester', 5), ('从根本', 5), ('那么容易', 1), ('毫无疑', 0), ('.RequestMethod', 0), ('utherland', 0), ('很开心', 0), (' strugg', 0)]
# MLP output [('/Dk', 50), ('weeney', 11), ('icester', 5), ('从根本', 5), ('那么容易', 1), ('毫无疑', 0), ('.RequestMethod', 0), ('utherland', 0), ('很开心', 0), (' strugg', 0)]
# Block output [('/Dk', 50), ('weeney', 11), ('icester', 5), ('从根本', 5), ('那么容易', 1), ('毫无疑', 0), ('.RequestMethod', 0), ('utherland', 0), ('很开心', 0), (' strugg', 0)]
# Layer 7: Decoded intermediate outputs
# Attention mechanism [("'+\n", 20), ('?>/', 6), ('有的玩家', 5), ('CADE', 3), (',No', 2), ('bsolute', 2), ('osals', 2), ('："+', 1), ('LLU', 1), ('[ID', 1)]
# Intermediate residual stream [('/Dk', 48), ('icester', 39), (' strugg', 0), ('paralleled', 0), (':white', 0), ('serter', 0), (']|[', 0), ("].'", 0), ('▿', 0), ('};\r\n\r\n\r\n', 0)]
# MLP output [('/Dk', 48), ('icester', 39), (' strugg', 0), ('paralleled', 0), (':white', 0), ('serter', 0), (']|[', 0), ("].'", 0), ('▿', 0), ('};\r\n\r\n\r\n', 0)]
# Block output [('/Dk', 48), ('icester', 39), (' strugg', 0), ('paralleled', 0), (':white', 0), ('serter', 0), (']|[', 0), ("].'", 0), ('▿', 0), ('};\r\n\r\n\r\n', 0)]
# Layer 8: Decoded intermediate outputs
# Attention mechanism [(' (~(', 12), ('-basket', 9), (' (;;)', 4), (' ragaz', 2), ('bsolute', 2), ('/Instruction', 1), ('/\n\n\n\n', 1), ('*)_', 1), ('$MESS', 1), (' gratuites', 1)]
# Intermediate residual stream [('/Dk', 95), ('icester', 1), ('paralleled', 0), ('℉', 0), (' strugg', 0), ('.omg', 0), ('utherland', 0), (' 生命周期', 0), (']=$', 0), ('-Cs', 0)]
# MLP output [('/Dk', 95), ('icester', 1), ('paralleled', 0), ('℉', 0), (' strugg', 0), ('.omg', 0), ('utherland', 0), (' 生命周期', 0), (']=$', 0), ('-Cs', 0)]
# Block output [('/Dk', 95), ('icester', 1), ('paralleled', 0), ('℉', 0), (' strugg', 0), ('.omg', 0), ('utherland', 0), (' 生命周期', 0), (']=$', 0), ('-Cs', 0)]
# Layer 9: Decoded intermediate outputs
# Attention mechanism [('下面是小', 20), ('bió', 6), ('.ERR', 6), (' atof', 4), (' Publié', 2), (' pestic', 1), (' vidé', 0), (' Aç', 0), ('lehem', 0), ('économ', 0)]
# Intermediate residual stream [('/Dk', 90), ('icester', 1), ('paralleled', 0), ('utherland', 0), ('?>>', 0), ('serter', 0), (' 生命周期', 0), ('/Instruction', 0), ('/respond', 0), ('WithType', 0)]
# MLP output [('/Dk', 90), ('icester', 1), ('paralleled', 0), ('utherland', 0), ('?>>', 0), ('serter', 0), (' 生命周期', 0), ('/Instruction', 0), ('/respond', 0), ('WithType', 0)]
# Block output [('/Dk', 90), ('icester', 1), ('paralleled', 0), ('utherland', 0), ('?>>', 0), ('serter', 0), (' 生命周期', 0), ('/Instruction', 0), ('/respond', 0), ('WithType', 0)]
# Layer 10: Decoded intermediate outputs
# Attention mechanism [(' Scrolls', 15), ('úmer', 10), (' GANG', 2), (' Booster', 1), (' Wants', 1), ('idel', 0), (' Girlfriend', 0), (' Decomp', 0), (' AGAIN', 0), (' Suggestions', 0)]
# Intermediate residual stream [('icester', 28), ('/Dk', 22), ('endet', 3), ('paralleled', 2), ('traîn', 2), (' 生命周期', 1), ('?>>', 0), ('/Instruction', 0), ('<main', 0), ('(IDC', 0)]
# MLP output [('icester', 28), ('/Dk', 22), ('endet', 3), ('paralleled', 2), ('traîn', 2), (' 生命周期', 1), ('?>>', 0), ('/Instruction', 0), ('<main', 0), ('(IDC', 0)]
# Block output [('icester', 28), ('/Dk', 22), ('endet', 3), ('paralleled', 2), ('traîn', 2), (' 生命周期', 1), ('?>>', 0), ('/Instruction', 0), ('<main', 0), ('(IDC', 0)]
# Layer 11: Decoded intermediate outputs
# Attention mechanism [('traî', 7), (',eg', 3), ('raits', 2), (" ');\r\n", 2), ('-valu', 1), (';z', 1), ('Ứ', 1), (' !***', 1), (' Leak', 1), ('羕', 1)]
# Intermediate residual stream [('paralleled', 12), ('icester', 8), ('endet', 4), ('serter', 4), ('/Dk', 4), ('/respond', 3), ('ubbo', 3), ('<main', 2), ('女性朋友', 2), ('traîn', 2)]
# MLP output [('paralleled', 12), ('icester', 8), ('endet', 4), ('serter', 4), ('/Dk', 4), ('/respond', 3), ('ubbo', 3), ('<main', 2), ('女性朋友', 2), ('traîn', 2)]
# Block output [('paralleled', 12), ('icester', 8), ('endet', 4), ('serter', 4), ('/Dk', 4), ('/respond', 3), ('ubbo', 3), ('<main', 2), ('女性朋友', 2), ('traîn', 2)]
# Layer 12: Decoded intermediate outputs
# Attention mechanism [('.ERR', 3), (' pestic', 3), (' Rencontre', 1), ('põe', 1), ('mäßig', 1), ('.ErrorCode', 1), ('lógica', 1), ('VISIBLE', 1), ('bucks', 0), (' suce', 0)]
# Intermediate residual stream [('traîn', 55), ('serter', 5), ('endet', 2), ('/respond', 1), ('<main', 1), ('/Dk', 1), ('/Instruction', 1), ('女性朋友', 0), ('quine', 0), ('ourcem', 0)]
# MLP output [('traîn', 55), ('serter', 5), ('endet', 2), ('/respond', 1), ('<main', 1), ('/Dk', 1), ('/Instruction', 1), ('女性朋友', 0), ('quine', 0), ('ourcem', 0)]
# Block output [('traîn', 55), ('serter', 5), ('endet', 2), ('/respond', 1), ('<main', 1), ('/Dk', 1), ('/Instruction', 1), ('女性朋友', 0), ('quine', 0), ('ourcem', 0)]
# Layer 13: Decoded intermediate outputs
# Attention mechanism [('////////////////////////////////////////////////////', 8), ('/Internal', 3), (' manh', 2), (' iht', 1), (' pestic', 1), ('celain', 1), ('traî', 1), ('bió', 0), (' GRAT', 0), ('ismic', 0)]
# Intermediate residual stream [('traîn', 15), ('};\r\n\r\n\r\n', 6), ('女性朋友', 4), ('/respond', 2), ('.MouseAdapter', 2), ('cede', 2), ('/Dk', 2), ('icester', 1), ('paralleled', 1), ('但不限', 0)]
# MLP output [('traîn', 15), ('};\r\n\r\n\r\n', 6), ('女性朋友', 4), ('/respond', 2), ('.MouseAdapter', 2), ('cede', 2), ('/Dk', 2), ('icester', 1), ('paralleled', 1), ('但不限', 0)]
# Block output [('traîn', 15), ('};\r\n\r\n\r\n', 6), ('女性朋友', 4), ('/respond', 2), ('.MouseAdapter', 2), ('cede', 2), ('/Dk', 2), ('icester', 1), ('paralleled', 1), ('但不限', 0)]
# Layer 14: Decoded intermediate outputs
# Attention mechanism [(':disable', 6), ('*****\n\n', 3), ('[ip', 2), ('ないです', 2), ('&action', 2), (" ');\r\n", 1), ('atee', 1), ('".$_', 1), ('.Age', 0), (' Tie', 0)]
# Intermediate residual stream [('icester', 9), ('paralleled', 5), ('/respond', 4), ('/Dk', 4), ('};\r\n\r\n\r\n', 3), ('女性朋友', 3), ('traîn', 2), (':white', 2), ('/Instruction', 1), ('<main', 1)]
# MLP output [('icester', 9), ('paralleled', 5), ('/respond', 4), ('/Dk', 4), ('};\r\n\r\n\r\n', 3), ('女性朋友', 3), ('traîn', 2), (':white', 2), ('/Instruction', 1), ('<main', 1)]
# Block output [('icester', 9), ('paralleled', 5), ('/respond', 4), ('/Dk', 4), ('};\r\n\r\n\r\n', 3), ('女性朋友', 3), ('traîn', 2), (':white', 2), ('/Instruction', 1), ('<main', 1)]
# Layer 15: Decoded intermediate outputs
# Attention mechanism [('-basket', 22), (' sağlıklı', 4), ('alyzed', 2), (' manh', 2), (' sın', 1), (' pestic', 1), (' hastalık', 1), (' geleceği', 1), (' tecrübe', 1), (' lã', 0)]
# Intermediate residual stream [('/Dk', 8), ('icester', 4), ('/respond', 3), ('}\n\n\n\n\n\n', 2), (' lokale', 1), ('女性朋友', 1), ('atisch', 1), ('做的事', 1), ('.MouseAdapter', 1), (' BaseEntity', 1)]
# MLP output [('/Dk', 8), ('icester', 4), ('/respond', 3), ('}\n\n\n\n\n\n', 2), (' lokale', 1), ('女性朋友', 1), ('atisch', 1), ('做的事', 1), ('.MouseAdapter', 1), (' BaseEntity', 1)]
# Block output [('/Dk', 8), ('icester', 4), ('/respond', 3), ('}\n\n\n\n\n\n', 2), (' lokale', 1), ('女性朋友', 1), ('atisch', 1), ('做的事', 1), ('.MouseAdapter', 1), (' BaseEntity', 1)]
# Layer 16: Decoded intermediate outputs
# Attention mechanism [(' manh', 17), ('traî', 2), ('lógica', 1), ('bió', 1), (' pestic', 1), (' GRAT', 0), (' fkk', 0), (' acheter', 0), ('.Generation', 0), (' ún', 0)]
# Intermediate residual stream [('/Dk', 6), (' lokale', 6), ('icester', 5), ('做的事', 2), ('室友', 2), ('女性朋友', 1), ('}\n\n\n\n\n\n', 1), ('}}],\n', 1), ('},{\n', 1), ('开工建设', 1)]
# MLP output [('/Dk', 6), (' lokale', 6), ('icester', 5), ('做的事', 2), ('室友', 2), ('女性朋友', 1), ('}\n\n\n\n\n\n', 1), ('}}],\n', 1), ('},{\n', 1), ('开工建设', 1)]
# Block output [('/Dk', 6), (' lokale', 6), ('icester', 5), ('做的事', 2), ('室友', 2), ('女性朋友', 1), ('}\n\n\n\n\n\n', 1), ('}}],\n', 1), ('},{\n', 1), ('开工建设', 1)]
# Layer 17: Decoded intermediate outputs
# Attention mechanism [('läuft', 16), ('.ShouldBe', 1), ('traî', 1), ('körper', 1), ('[right', 0), ('móvel', 0), ('acje', 0), ('.BigInteger', 0), ('wię', 0), ('/live', 0)]
# Intermediate residual stream [('icester', 14), (' lokale', 4), ('做的事', 3), ('}}],\n', 2), ('.easing', 2), ("');\n\n\n\n", 1), ('WithPath', 1), ('/Instruction', 1), ('="/">', 1), ('.StatusOK', 1)]
# MLP output [('icester', 14), (' lokale', 4), ('做的事', 3), ('}}],\n', 2), ('.easing', 2), ("');\n\n\n\n", 1), ('WithPath', 1), ('/Instruction', 1), ('="/">', 1), ('.StatusOK', 1)]
# Block output [('icester', 14), (' lokale', 4), ('做的事', 3), ('}}],\n', 2), ('.easing', 2), ("');\n\n\n\n", 1), ('WithPath', 1), ('/Instruction', 1), ('="/">', 1), ('.StatusOK', 1)]
# Layer 18: Decoded intermediate outputs
# Attention mechanism [(' punched', 3), (' cuckold', 2), ('lan', 1), ('噱', 1), ('raison', 1), (' disadv', 1), ('getParam', 0), (' AppState', 0), ('prix', 0), (' punching', 0)]
# Intermediate residual stream [('icester', 35), (' lokale', 3), ('/Dk', 1), ('="/">', 1), ('benh', 1), ('{/*', 1), ('.easing', 1), ('stakes', 1), ('ipline', 1), ('ideshow', 0)]
# MLP output [('icester', 35), (' lokale', 3), ('/Dk', 1), ('="/">', 1), ('benh', 1), ('{/*', 1), ('.easing', 1), ('stakes', 1), ('ipline', 1), ('ideshow', 0)]
# Block output [('icester', 35), (' lokale', 3), ('/Dk', 1), ('="/">', 1), ('benh', 1), ('{/*', 1), ('.easing', 1), ('stakes', 1), ('ipline', 1), ('ideshow', 0)]
# Layer 19: Decoded intermediate outputs
# Attention mechanism [(' $\r\n', 8), (' manh', 7), ('-scalable', 3), (':black', 2), ('anmar', 2), (':white', 1), (' Vivo', 1), (' )))', 1), ('MUX', 1), (':;"', 0)]
# Intermediate residual stream [('/Dk', 13), (':white', 7), ('____', 2), ('icester', 2), ("');\n\n\n\n", 2), ('{/*', 2), (':red', 1), ('ipline', 1), ('์', 1), (' ____', 1)]
# MLP output [('/Dk', 13), (':white', 7), ('____', 2), ('icester', 2), ("');\n\n\n\n", 2), ('{/*', 2), (':red', 1), ('ipline', 1), ('์', 1), (' ____', 1)]
# Block output [('/Dk', 13), (':white', 7), ('____', 2), ('icester', 2), ("');\n\n\n\n", 2), ('{/*', 2), (':red', 1), ('ipline', 1), ('์', 1), (' ____', 1)]
# Layer 20: Decoded intermediate outputs
# Attention mechanism [(' moc', 6), ('capital', 1), (' Lara', 1), ('性价', 1), ('aseline', 1), ('ledon', 0), ('ecure', 0), ('��', 0), ('详细的', 0), ('友善', 0)]
# Intermediate residual stream [('/Dk', 7), ('serter', 6), ('icester', 3), ('ipline', 1), (' BaseEntity', 1), ('=findViewById', 1), ('{/*', 1), ('℠', 0), ('=\'".$_', 0), ("');\n\n\n\n", 0)]
# MLP output [('/Dk', 7), ('serter', 6), ('icester', 3), ('ipline', 1), (' BaseEntity', 1), ('=findViewById', 1), ('{/*', 1), ('℠', 0), ('=\'".$_', 0), ("');\n\n\n\n", 0)]
# Block output [('/Dk', 7), ('serter', 6), ('icester', 3), ('ipline', 1), (' BaseEntity', 1), ('=findViewById', 1), ('{/*', 1), ('℠', 0), ('=\'".$_', 0), ("');\n\n\n\n", 0)]
# Layer 21: Decoded intermediate outputs
# Attention mechanism [(':<?', 44), ('所有情节', 16), ('喟', 3), (';};\n', 1), ('@Id', 1), (')(__', 1), ('TransparentColor', 0), (')index', 0), ('可想而', 0), (';left', 0)]
# Intermediate residual stream [('/Dk', 18), ('},{\n', 5), ('____', 4), (' gql', 1), ('�', 1), (' BaseEntity', 1), (' ____', 0), ('=\'".$_', 0), ('ThanOrEqualTo', 0), ('{/*', 0)]
# MLP output [('/Dk', 18), ('},{\n', 5), ('____', 4), (' gql', 1), ('�', 1), (' BaseEntity', 1), (' ____', 0), ('=\'".$_', 0), ('ThanOrEqualTo', 0), ('{/*', 0)]
# Block output [('/Dk', 18), ('},{\n', 5), ('____', 4), (' gql', 1), ('�', 1), (' BaseEntity', 1), (' ____', 0), ('=\'".$_', 0), ('ThanOrEqualTo', 0), ('{/*', 0)]
# Layer 22: Decoded intermediate outputs
# Attention mechanism [('在北京', 74), (' Beijing', 15), ('北京', 7), ('北京市', 1), (' China', 0), ('在京', 0), ('京', 0), ('China', 0), ('胡同', 0), ('中国政府', 0)]
# Intermediate residual stream [('/Dk', 34), ('bish', 6), (' gql', 1), ('},{\n', 1), ('icester', 1), (')(((', 0), ('\xa0', 0), ('首都', 0), ('.openConnection', 0), ('atat', 0)]
# MLP output [('/Dk', 34), ('bish', 6), (' gql', 1), ('},{\n', 1), ('icester', 1), (')(((', 0), ('\xa0', 0), ('首都', 0), ('.openConnection', 0), ('atat', 0)]
# Block output [('/Dk', 34), ('bish', 6), (' gql', 1), ('},{\n', 1), ('icester', 1), (')(((', 0), ('\xa0', 0), ('首都', 0), ('.openConnection', 0), ('atat', 0)]
# Layer 23: Decoded intermediate outputs
# Attention mechanism [('在北京', 52), (' Beijing', 35), ('北京', 12), ('北京市', 0), ('京', 0), ('在京', 0), (' Chinese', 0), ('-China', 0), (' China', 0), ('首都', 0)]
# Intermediate residual stream [(' Beijing', 32), ('北京', 14), (' Washington', 8), ('首都', 6), ('/Dk', 4), ('京', 1), (' กร', 1), ('____', 1), ('\xa0', 0), (' capitals', 0)]
# MLP output [(' Beijing', 32), ('北京', 14), (' Washington', 8), ('首都', 6), ('/Dk', 4), ('京', 1), (' กร', 1), ('____', 1), ('\xa0', 0), (' capitals', 0)]
# Block output [(' Beijing', 32), ('北京', 14), (' Washington', 8), ('首都', 6), ('/Dk', 4), ('京', 1), (' กร', 1), ('____', 1), ('\xa0', 0), (' capitals', 0)]
# Layer 24: Decoded intermediate outputs
# Attention mechanism [('ably', 5), ('typeparam', 1), ('城市的', 1), (' hvordan', 1), ('riad', 0), ('-pills', 0), (' demos', 0), (' Clo', 0), ('托运', 0), (' visited', 0)]
# Intermediate residual stream [(' capital', 52), ('首都', 13), (' Capital', 11), (' Beijing', 8), ('capital', 2), (' capitals', 2), ('北京', 1), (' Washington', 0), ('Capital', 0), (' capitalize', 0)]
# MLP output [(' capital', 52), ('首都', 13), (' Capital', 11), (' Beijing', 8), ('capital', 2), (' capitals', 2), ('北京', 1), (' Washington', 0), ('Capital', 0), (' capitalize', 0)]
# Block output [(' capital', 52), ('首都', 13), (' Capital', 11), (' Beijing', 8), ('capital', 2), (' capitals', 2), ('北京', 1), (' Washington', 0), ('Capital', 0), (' capitalize', 0)]
# Layer 25: Decoded intermediate outputs
# Attention mechanism [(' iar', 20), ('在网络上', 14), ('睥', 12), (' oppon', 4), ('戕', 2), ('ribly', 1), ('袆', 1), (' __', 0), ('钫', 0), ('__', 0)]
# Intermediate residual stream [(' Capital', 38), (' capital', 26), (' Beijing', 14), ('．', 2), ('北京', 1), ('首都', 1), ('____', 1), ('Capital', 1), ('\xa0', 0), ('capital', 0)]
# MLP output [(' Capital', 38), (' capital', 26), (' Beijing', 14), ('．', 2), ('北京', 1), ('首都', 1), ('____', 1), ('Capital', 1), ('\xa0', 0), ('capital', 0)]
# Block output [(' Capital', 38), (' capital', 26), (' Beijing', 14), ('．', 2), ('北京', 1), ('首都', 1), ('____', 1), ('Capital', 1), ('\xa0', 0), ('capital', 0)]
# Layer 26: Decoded intermediate outputs
# Attention mechanism [(' ', 94), ('3', 0), (' “', 0), (',', 0), ('4', 0), (' "', 0), ('“', 0), ('2', 0), (' B', 0), (' �', 0)]
# Intermediate residual stream [(' Beijing', 16), (' Capital', 9), (' capital', 7), (' ', 6), ('．', 5), (' Be', 3), ('北京', 3), (' (', 2), ('(Be', 1), (' .', 1)]
# MLP output [(' Beijing', 16), (' Capital', 9), (' capital', 7), (' ', 6), ('．', 5), (' Be', 3), ('北京', 3), (' (', 2), ('(Be', 1), (' .', 1)]
# Block output [(' Beijing', 16), (' Capital', 9), (' capital', 7), (' ', 6), ('．', 5), (' Be', 3), ('北京', 3), (' (', 2), ('(Be', 1), (' .', 1)]
# Layer 27: Decoded intermediate outputs
# Attention mechanism [('疥', 2), ('opcion', 1), ('很方便', 0), ('ortic', 0), ('这么久', 0), ('GetComponent', 0), ('瘰', 0), (' GenerationType', 0), (' Rencontres', 0), ('esteem', 0)]
# Intermediate residual stream [('．', 48), (' Beijing', 25), (' Be', 4), (' __', 2), (' .', 2), (' _', 2), (' ____', 1), (' $\\', 1), (' (', 1), (' be', 0)]
# MLP output [('．', 48), (' Beijing', 25), (' Be', 4), (' __', 2), (' .', 2), (' _', 2), (' ____', 1), (' $\\', 1), (' (', 1), (' be', 0)]
# Block output [('．', 48), (' Beijing', 25), (' Be', 4), (' __', 2), (' .', 2), (' _', 2), (' ____', 1), (' $\\', 1), (' (', 1), (' be', 0)]

# %%
=+model.reset_all()
layer = 14
model.get_logits('bananas')
attn = model.get_attn_activations(layer)
last_token_attn = attn[0][-1]
model.set_add_attn_output(layer, 0.6*last_token_attn)

# %%
model.generate_text(prompt, max_length=20)

# %%
model.reset_all()
